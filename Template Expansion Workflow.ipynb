# %% [markdown]
# # Toolbox Template Expansion as a Service - Workflow
#
#
# ### Workflow Template and Binding Document
#
# The cell below shows the example of a JSON binding document, *workflow_binding*, used to expand the PROV-Template that models the general execution information a Toolbox workflow. The binding examplifies an execution of the **Calculate Trends** workflows that is parametrised with *Europe* (***parval***) as the *Region* (**parkey**) of interest for the analysis.
#
# The variable *tool_binding* instead exmplifies the lineage information associated to the execution of the *monthly_mean*, being this tool part of the **Calculate Trends** workflow.
#
# The templates are avalable at the following addresses for consultation.
#
# worklfow execution
# https://openprovenance.org/store/documents/1058
#
# single tool lineage
# https://openprovenance.org/store/documents/1059
#
# ### Software Requirements
#
# The following python and prov modules are used by this notebook
#
# *python = 3.7.2*
#
# *prov = 1.5.1*
#
# The remote Provenance Template Catalogue can be downloaded and installed through Docker, as explained here
#
# https://github.com/EnvriPlus-PROV/ProvTemplateCatalog#setup-using-docker
#
#
# ### Local Expansion With ProvToolbox
#
# The bindings presented in this notebook can be expanded also by using the ProvToolbox
#
# https://lucmoreau.github.io/ProvToolbox/
#
# Command line execution example:
#
# ```
# provconvert -infile template.provn  -bindings binding.json  -outfile doc.json -bindver 3
#
# ```

# %%
workflow_binding="""

   {
  "var" : {
   "WFExecution":[{"@id":"uuid:wfrun00001"}],
   "toolbox":[{"@id":"uuid:C3SToolBox0001"}],
   "Workflow":[{"@id":"uuid:Workflow0001"}],
   "wfname":["Calculate Trends"],
   "wftype":["c3s:Trend"],
   "parval": ["Europe"],
   "parameter":[{"@id":"uuid:wfpar0001"}],
   "parkey":["Region"],
   "accessUrlOut":["https://cds.data/91991343"],
   "accessUrlInp":["https://cds.data/9199194"],
   "version":["v0.5"],
   "wfversion":["v0.8"],
   "pid": ["52556"],
   "cresource":[{"@id":"uuid:DIAS_BCN"}],
   "worker": ["node4c3s"],
   "accessUrlDocumentation":["https://cds.climate.copernicus.eu/toolbox-editor/examples/31-calculate-trends"],
   "user":[{"@id": "http://orcid.org/0000-0002-3494-120X"}],
   "lib": [{"@id": "uuid:cdstoolbox10"}],
   "libname": ["cdstoolbox"],
   "libversion": ["v1.0"],
   "wfstart": ["2019-06-07T15:58:58Z"],
   "startedAt":["2019-06-07T15:51:58Z"],
   "generatedAt":["2019-06-07T15:58:58Z"]
  },
  "context" : {
  
      "prov": "http://www.w3.org/ns/prov#",
    "xsd": "http://www.w3.org/2001/XMLSchema#" ,
    "tmpl": "http://openprovenance.org/tmpl#" ,
    "var": "http://openprovenance.org/var#" ,
    "ex": "http://example.com/#" ,
    "mc": "http://www.metaclip.org/datasource/datasource.owl#",
    "http": "http:",
    "c3s": "http://www.c3s.org/#",
    
    
     "uuid": "urn:uuid:",
     "https": "https:"
   }
 }

"""


monthly_mean_binding="""
 {

  "var" : {
   "derivtype": ["c3s:Mean"],
   "toolbox":[{"@id":"uuid:C3SToolBox0001"}],
   "parval": ["23","True"],
   "WFexecution":["uuid:wfrun00001"],
   "parameter":[{"@id":"uuid:par0001"},{"@id":"uuid:par0002"}],
   "parkey":["baseint","keep_attrsbool"],
   "input": [{"@id":"uuid:91991554"}],
   "accessUrlOut":["https://cds.data/91991343"],
   "accessUrlInp":["https://cds.data/9199194"],
   "version":["v0.5"],
   "pid": ["12345"],
   "cresource":[{"@id":"uuid:DIAS_BCN"}],
   "worker": ["node6c3s"],
   "accessUrlDocumentation":["https://git.ecmwf.int/projects/CST/repos/cdstools/commits/7f4d184cf8f0638cedd4039a4293b8afb674f392#cdstools/season.py"],
   "user":[{"@id": "http://orcid.org/0000-0002-3494-120X"}],
   "tool": [{"@id":"uuid:monyhly_trend0001"}],
   "lib": [{"@id":"uuid:numpy10"},{"@id":"uuid:xarray20"}],
   "libname": ["numpy","xarray"],
   "libversion": ["v1.0","v2.0"],
   "executionStartTime": ["2019-06-07T15:58:58Z"],
   "executionEndTime":["2019-06-07T16:58:58Z"],
   "startedAt":["2019-06-07T15:51:58Z"],
   "generatedAt":["2019-06-07T15:58:58Z"]
  },
  "context" : {
  
     "prov": "http://www.w3.org/ns/prov#",
     "xsd": "http://www.w3.org/2001/XMLSchema#",
     "tmpl": "http://openprovenance.org/tmpl#",
     "var": "http://openprovenance.org/var#",
     "c3s": "http://linktovoc.org/#",
     "uuid": "urn:uuid:",
     "http": "http:" 
     

  }
}
"""

# %% [markdown]
# ### Execution of the Expansion as a service
#
# The template is stored in a test instance of the Proveance Template Catalog Service, deployed on AWS. The service enables its management and expansion.
#
# The script below refers to the templates' ids *workflow_template_id* and *tool_template_id* and uses the expansion service indicated by the variable *host_name*.
#
# The Provenance Catalgue's expansion service is invoked through a POST request.

# %%
import requests
from urllib.parse import urlencode, quote_plus


host_name = 'aa0a41f361f2d11e9a4ad0a964ab5068-808410469.eu-west-1.elb.amazonaws.com'
workflow_template_id = '5d5a74a802444c000db79792'
tool_template_id = '5d52ab0402444c000db79791'


workflow = requests.post('https://' + host_name + '/templates/' + workflow_template_id + 
    '/expand?fmt=provjson&writeprov=false&bindver=v3',
        data=workflow_binding, verify=False)


monthly_mean = requests.post('https://' + host_name + '/templates/' + tool_template_id + 
    '/expand?fmt=provjson&writeprov=false&bindver=v3',
        data=monthly_mean_binding, verify=False)

print(workflow.text)

print(monthly_mean.text)
# Out:
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {"prefix": {"tmpl": "http://openprovenance.org/tmpl#", "http": "http:", "uuid": "urn:uuid:", "mc": "http://www.metaclip.org/datasource/datasource.owl#", "ex": "http://example.com/#", "https": "https:", "var": "http://openprovenance.org/var#", "c3s": "http://www.c3s.org/#"}, "bundle": {"uuid:ToolboxWorkflowExecution": {"wasAssociatedWith": {"_:id2": {"prov:plan": "uuid:wfrun00001", "prov:agent": "uuid:Workflow0001", "prov:activity": "uuid:C3SToolBox0001"}}, "hadMember": {"_:id5": {"prov:collection": "uuid:c7ec7a32-a08c-4980-9221-b60f85784d67", "prov:entity": "uuid:cdstoolbox10"}, "_:id4": {"prov:collection": "uuid:2099d806-91e5-499e-b16a-c538983998a9", "prov:entity": "uuid:wfpar0001"}, "_:id6": {"prov:collection": "uuid:Workflow0001", "prov:entity": "uuid:c7ec7a32-a08c-4980-9221-b60f85784d67"}}, "used": {"_:id1": {"prov:entity": "uuid:2099d806-91e5-499e-b16a-c538983998a9", "prov:activity": "uuid:wfrun00001"}}, "wasStartedBy": {"_:id3": {"var:parterm": {"type": "prov:QUALIFIED_NAME", "$": "var:termval"}, "prov:time": "2019-06-07T15:51:58+00:00", "prov:trigger": "http://orcid.org/0000-0002-3494-120X", "prov:activity": "uuid:wfrun00001"}}, "agent": {"uuid:C3SToolBox0001": {"c3s:version": "v0.5", "prov:atLocation": {"type": "prov:QUALIFIED_NAME", "$": "var:accessUrl"}, "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "prov:SoftwareAgent"}}, "http://orcid.org/0000-0002-3494-120X": {"prov:type": {"type": "prov:QUALIFIED_NAME", "$": "prov:Person"}, "vcard:uid": {"type": "prov:QUALIFIED_NAME", "$": "var:name"}}}, "entity": {"uuid:c7ec7a32-a08c-4980-9221-b60f85784d67": {"prov:type": {"type": "prov:QUALIFIED_NAME", "$": "c3s:LibCollection"}}, "uuid:DIAS_BCN": {"s-prov:queue": {"type": "prov:QUALIFIED_NAME", "$": "var:queue"}, "s-prov:resourceType": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceType"}, "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "s-prov:CResource"}, "s-prov:resourceUrl": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceUrl"}, "s-prov:modules": {"type": "prov:QUALIFIED_NAME", "$": "var:modules"}, "s-prov:mapping": {"type": "prov:QUALIFIED_NAME", "$": "var:mapping"}, "s-prov:resourceName": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceName"}}, "uuid:Workflow0001": {"c3s:version": "v0.8", "prov:atLocation": "https://cds.climate.copernicus.eu/toolbox-editor/examples/31-calculate-trends", "c3s:sourcecode": "var:sourcecode", "prov:type": "c3s:Trend", "prov:name": "Calculate Trends"}, "uuid:cdstoolbox10": {"c3s:version": "v1.0", "c3s:libname": "cdstoolbox", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "var:dependencyConcept"}}, "uuid:wfpar0001": {"c3s:parkey": "Region", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "c3s:WorkflowParameter"}, "c3s:parvalue": "Europe"}, "uuid:2099d806-91e5-499e-b16a-c538983998a9": {"prov:type": "s-prov:WFExecutionInputs"}, "uuid:9be7c35b-1207-4b10-87c5-a191e921c6bf": {"c3s:pid": "52556", "c3s:cresource": {"type": "prov:QUALIFIED_NAME", "$": "uuid:DIAS_BCN"}, "c3s:worker": "node4c3s"}}, "prefix": {"http": "http:", "uuid": "urn:uuid:", "s-prov": "https://github.com/aspinuso/s-provenance/blob/master/resources/s-prov-o.owl", "var": "http://openprovenance.org/var#", "vcard": "http://www.w3.org/2006/vcard/ns#", "c3s": "http://linktovoc.org/#"}, "activity": {"uuid:wfrun00001": {"prov:atLocation": {"type": "prov:QUALIFIED_NAME", "$": "uuid:9be7c35b-1207-4b10-87c5-a191e921c6bf"}, "prov:startTime": "2019-06-07T15:58:58+00:00", "s-prov:runId": {"type": "prov:QUALIFIED_NAME", "$": "uuid:wfrun00001"}, "prov:type": "s-prov:WFExecution", "s-prov:description": "var:e"}}}}}
# {"prefix": {"tmpl": "http://openprovenance.org/tmpl#", "http": "http:", "uuid": "urn:uuid:", "var": "http://openprovenance.org/var#", "vargen": "http://openprovenance.org/vargen#", "c3s": "http://linktovoc.org/#"}, "bundle": {"uuid:8440d338-725b-4333-8c9a-45125a5d794f": {"wasAssociatedWith": {"_:id4": {"prov:plan": "uuid:db95572e-d923-435a-92e4-6f34ab815686", "prov:agent": "uuid:monyhly_trend0001", "prov:activity": "uuid:C3SToolBox0001"}}, "wasDerivedFrom": {"_:id5": {"prov:usedEntity": "uuid:91991554", "prov:generatedEntity": "uuid:23572461-7b4e-4229-9c80-817e7a607dca", "prov:type": "c3s:Mean"}}, "used": {"_:id1": {"prov:entity": "uuid:91991554", "prov:activity": "uuid:db95572e-d923-435a-92e4-6f34ab815686"}, "_:id3": {"prov:entity": "uuid:par0002", "prov:activity": "uuid:db95572e-d923-435a-92e4-6f34ab815686"}, "_:id2": {"prov:entity": "uuid:par0001", "prov:activity": "uuid:db95572e-d923-435a-92e4-6f34ab815686"}}, "hadMember": {"_:id9": {"prov:collection": "uuid:a3e5b2c7-05f2-452a-b2a7-10b495be0e6a", "prov:entity": "uuid:numpy10"}, "_:id8": {"prov:collection": "uuid:monyhly_trend0001", "prov:entity": "uuid:a3e5b2c7-05f2-452a-b2a7-10b495be0e6a"}, "_:id10": {"prov:collection": "uuid:a3e5b2c7-05f2-452a-b2a7-10b495be0e6a", "prov:entity": "uuid:xarray20"}}, "wasStartedBy": {"_:id6": {"var:parterm": {"type": "prov:QUALIFIED_NAME", "$": "var:termval"}, "prov:time": "2019-06-07T15:51:58+00:00", "prov:trigger": "http://orcid.org/0000-0002-3494-120X", "prov:activity": "uuid:db95572e-d923-435a-92e4-6f34ab815686"}}, "agent": {"uuid:C3SToolBox0001": {"c3s:version": "v0.5", "prov:atLocation": {"type": "prov:QUALIFIED_NAME", "$": "var:accessUrl"}, "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "prov:SoftwareAgent"}}, "http://orcid.org/0000-0002-3494-120X": {"prov:type": {"type": "prov:QUALIFIED_NAME", "$": "prov:Person"}, "vcard:uid": {"type": "prov:QUALIFIED_NAME", "$": "var:name"}}}, "entity": {"uuid:DIAS_BCN": {"s-prov:queue": {"type": "prov:QUALIFIED_NAME", "$": "var:queue"}, "s-prov:resourceType": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceType"}, "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "s-prov:CResource"}, "s-prov:resourceUrl": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceUrl"}, "s-prov:modules": {"type": "prov:QUALIFIED_NAME", "$": "var:modules"}, "s-prov:mapping": {"type": "prov:QUALIFIED_NAME", "$": "var:mapping"}, "s-prov:resourceName": {"type": "prov:QUALIFIED_NAME", "$": "var:resourceName"}}, "uuid:monyhly_trend0001": {"c3s:version": "v0.5", "prov:atLocation": "https://git.ecmwf.int/projects/CST/repos/cdstools/commits/7f4d184cf8f0638cedd4039a4293b8afb674f392#cdstools/season.py", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "var:tooltype"}}, "uuid:numpy10": {"c3s:version": "v1.0", "c3s:libname": "numpy", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "var:dependencyConcept"}}, "uuid:par0002": {"c3s:parkey": "keep_attrsbool", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "c3s:ToolParameter"}, "c3s:parvalue": "True"}, "uuid:par0001": {"c3s:parkey": "baseint", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "c3s:ToolParameter"}, "c3s:parvalue": "23"}, "uuid:23572461-7b4e-4229-9c80-817e7a607dca": {"prov:atLocation": "https://cds.data/91991343", "prov:generatedAt": "2019-06-07T15:58:58Z", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "provone:Data"}}, "uuid:a3e5b2c7-05f2-452a-b2a7-10b495be0e6a": {"prov:type": {"type": "prov:QUALIFIED_NAME", "$": "c3s:LibCollection"}}, "uuid:91991554": {"prov:atLocation": "https://cds.data/9199194", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "provone:Data"}, "c3s:inputName": {"type": "prov:QUALIFIED_NAME", "$": "var:inputName"}}, "uuid:71e44b70-762c-4f87-89be-90463df194fd": {"c3s:pid": "12345", "prov:type": {"type": "prov:QUALIFIED_NAME", "$": "s-prov:SystemProcess"}, "c3s:cresource": {"type": "prov:QUALIFIED_NAME", "$": "uuid:DIAS_BCN"}, "c3s:worker": "node6c3s"}, "uuid:xarray20": {"c3s:version": "v2.0", "c3s:libname": "xarray", "prov:type": {"type": "p ...
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ### Visualisation
#
# Thanks to the https://pypi.org/project/prov/ module the single documents can be visualised as follows.

# %%
from prov.serializers.provjson import ProvJSONSerializer
from IPython.display import Image
import io
from prov.model import ProvDocument, ProvBundle, ProvException, first, Literal
from prov.dot import prov_to_dot

def provJSONtoPNG(doc,format):
     
    
    doc=ProvJSONSerializer.deserialize(ProvJSONSerializer,doc)
    dot = prov_to_dot(doc)
    
    if format=="png":
        dot.write_png('PROV.png')
        return 'PROV.png' 
    if format=="svg":
        dot.write_svg('PROV.svg')
        return 'PROV.svg'
    
    

w = io.StringIO(workflow.text)
png_content=provJSONtoPNG(w,"png")


 

Image(png_content)

# %%
t = io.StringIO(monthly_mean.text)
png_content=provJSONtoPNG(t,"png")

Image(png_content)

# %% [markdown]
# ### Meriging in a single view
#
# The two single documents can be merged into one, where all the entities are connected in a comprehensive view.

# %%
doc_tool=ProvJSONSerializer.deserialize(ProvJSONSerializer,io.StringIO(monthly_mean.text))
doc_workflow=ProvJSONSerializer.deserialize(ProvJSONSerializer,io.StringIO(workflow.text))
doc_workflow.add_bundle(list(doc_tool.bundles)[0])

png_content=provJSONtoPNG(io.StringIO(doc_workflow.flattened().serialize()),"png")

Image(png_content)
